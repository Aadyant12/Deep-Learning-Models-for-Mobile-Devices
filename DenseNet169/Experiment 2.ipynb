# %% [markdown]
# ### **HERE EXIT NETWORKS HAVE BEEN ADDED IN DenseNet169 NETWORK**

# %%
from tensorflow.keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
from keras.applications.densenet import DenseNet169
model = DenseNet169(include_top=False, weights= None, input_shape=(32, 32, 3))
# summarize the model
model.summary()
# Out:
# Model: "densenet169"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
len(model.layers)
# Out:
# 595

# %%
import tensorflow as tf
from keras.models import Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D

# %%
exits = [52, 94, 140, 196, 252, 308, 368, 424, 480, 536]

# %% [markdown]
# ## **ADDITION OF EXIT NETWORK**

# %%
exit_layer1 = model.layers[exits[0]]
exit_layer2 = model.layers[exits[1]]
exit_layer3 = model.layers[exits[2]]
exit_layer4 = model.layers[exits[3]]
exit_layer5 = model.layers[exits[4]]
exit_layer6 = model.layers[exits[5]]
exit_layer7 = model.layers[exits[6]]
exit_layer8 = model.layers[exits[7]]
exit_layer9 = model.layers[exits[8]]
exit_layer10 = model.layers[exits[9]]

# %%
exit_models = []

# %%
exit_layer1.output_shape
# Out:
# (None, 4, 4, 128)

# %%
pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer1.output)
conv1 = Conv2D(256, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(pool2)
class1 = Dense(128, activation='relu')(flat1)

prediction = Dense(10, activation='softmax')(class1)

exit_model1 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model1)
exit_model1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer2.output_shape
# Out:
# (None, 4, 4, 320)

# %%
pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer2.output)
conv1 = Conv2D(512, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(pool2)
class1 = Dense(128, activation='relu')(flat1)

prediction = Dense(10, activation='softmax')(class1)

exit_model2 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model2)
exit_model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer3.output_shape
# Out:
# (None, 2, 2, 256)

# %%
#pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer3.output)
conv1 = Conv2D(512, (3,3), padding='same', activation='relu')(exit_layer3.output)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(pool2)
class1 = Dense(512, activation='relu')(flat1)
class2 = Dense(128, activation='relu')(class1)
prediction = Dense(10, activation='softmax')(class2)

exit_model3 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model3)
exit_model3.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer4.output_shape
# Out:
# (None, 2, 2, 512)

# %%
pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer4.output)
#conv1 = Conv2D(1024, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
#pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(pool1)
#class1 = Dense(512, activation='relu')(flat1)
class2 = Dense(128, activation='relu')(flat1)
prediction = Dense(10, activation='softmax')(class2)

exit_model4 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model4)
exit_model4.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer5.output_shape
# Out:
# (None, 2, 2, 768)

# %%
pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer5.output)
#conv1 = Conv2D(1024, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
#pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(pool1)
class1 = Dense(512, activation='relu')(flat1)
class2 = Dense(128, activation='relu')(class1)
prediction = Dense(10, activation='softmax')(class2)

exit_model5 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model5)
exit_model5.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer6.output_shape
# Out:
# (None, 2, 2, 1024)

# %%
pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer6.output)
#conv1 = Conv2D(1024, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
#pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(pool1)
class1 = Dense(512, activation='relu')(flat1)
class2 = Dense(128, activation='relu')(class1)
prediction = Dense(10, activation='softmax')(class2)

exit_model6 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model6)
exit_model6.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer7.output_shape
# Out:
# (None, 1, 1, 640)

# %%
#pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer7.output)
#conv1 = Conv2D(1024, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
#pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(exit_layer7.output)
class1 = Dense(512, activation='relu')(flat1)
class2 = Dense(128, activation='relu')(class1)
prediction = Dense(10, activation='softmax')(class2)

exit_model7 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model7)
exit_model7.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer8.output_shape
# Out:
# (None, 1, 1, 896)

# %%
#pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer8.output)
#conv1 = Conv2D(1024, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
#pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(exit_layer8.output)
class1 = Dense(512, activation='relu')(flat1)
class2 = Dense(128, activation='relu')(class1)
prediction = Dense(10, activation='softmax')(class2)

exit_model8 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model8)
exit_model8.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer9.output_shape
# Out:
# (None, 1, 1, 1152)

# %%
#pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer9.output)
#conv1 = Conv2D(1024, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
#pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(exit_layer9.output)
class1 = Dense(512, activation='relu')(flat1)
class2 = Dense(128, activation='relu')(class1)
prediction = Dense(10, activation='softmax')(class2)

exit_model9 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model9)
exit_model9.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
exit_layer10.output_shape
# Out:
# (None, 1, 1, 1408)

# %%
#pool1 = MaxPooling2D((2,2), strides=(2,2))(exit_layer10.output)
#conv1 = Conv2D(1024, (3,3), padding='same', activation='relu')(pool1)
#conv2 = Conv2D(256, (5,5), padding='same', activation='relu')(conv1)
#pool2 = MaxPooling2D((2,2), strides=(2,2))(conv1)

flat1 = Flatten()(exit_layer10.output)
class1 = Dense(512, activation='relu')(flat1)
class2 = Dense(128, activation='relu')(class1)
prediction = Dense(10, activation='softmax')(class2)

exit_model10 = Model(inputs=model.inputs, outputs=prediction)
exit_models.append(exit_model10)
exit_model10.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 16, 16, 64)   0           conv1/bn[0][0]
# ...

# %%
len(exit_models)
# Out:
# 10

# %%
import time

# %%
for model in exit_models:
  model.compile(
          optimizer='adam',
          loss='sparse_categorical_crossentropy',
          metrics=['accuracy']
      )

# %%
i = 1
accuracies_time = []
for model in exit_models:
  accuracies_time.append('-------------')
  start = time.time()
  history = model.fit(
      x=x_train,
      y=y_train,
      epochs=100,
      verbose=1,
      validation_data=(x_test, y_test),
      batch_size=128
  )
  end = time.time()
  Model(inputs = model.inputs, outputs = model.layers[exits[i-1]].output).save_weights(f"/DenseNet169/EarlyExit_till_exit{i}_weights.h5")
  print("Saved!")
  accuracies_time.append(((history.history.get('val_accuracy')[19]), (end-start)*2/10))
  accuracies_time.append(((history.history.get('val_accuracy')[29]), (end-start)*3/10))
  accuracies_time.append(((history.history.get('val_accuracy')[39]), (end-start)*4/10))
  accuracies_time.append(((history.history.get('val_accuracy')[49]), (end-start)*5/10))
  accuracies_time.append(((history.history.get('val_accuracy')[59]), (end-start)*6/10))
  accuracies_time.append(((history.history.get('val_accuracy')[69]), (end-start)*7/10))
  accuracies_time.append(((history.history.get('val_accuracy')[79]), (end-start)*8/10))
  accuracies_time.append(((history.history.get('val_accuracy')[89]), (end-start)*9/10))
  accuracies_time.append(((history.history.get('val_accuracy')[99]), (end-start)*10/10))
  print(f"Accuracy of model {i}: ", history.history.get('val_accuracy')[len(history.history.get('val_accuracy')) - 1])
  i += 1
# Out:
# Epoch 1/100
# 391/391 [==============================] - 39s 17ms/step - loss: 1.5588 - accuracy: 0.4308 - val_loss: 1.3315 - val_accuracy: 0.5242
# Epoch 2/100
# 391/391 [==============================] - 5s 12ms/step - loss: 0.9614 - accuracy: 0.6580 - val_loss: 1.3316 - val_accuracy: 0.5387
# Epoch 3/100
# 391/391 [==============================] - 5s 12ms/step - loss: 0.7518 - accuracy: 0.7357 - val_loss: 1.4364 - val_accuracy: 0.5419
# Epoch 4/100
# 391/391 [==============================] - 5s 12ms/step - loss: 0.5994 - accuracy: 0.7880 - val_loss: 0.9745 - val_accuracy: 0.6655
# Epoch 5/100
# 391/391 [==============================] - 5s 12ms/step - loss: 0.4783 - accuracy: 0.8296 - val_loss: 1.1564 - val_accuracy: 0.6578
# Epoch 6/100
# 391/391 [==============================] - 5s 12ms/step - loss: 0.3883 - accuracy: 0.8650 - val_loss: 1.2504 - val_accuracy: 0.6269
# Epoch 7/100
# ...

# %%
accuracies_time
# Out:
# ['-------------',
#  (0.691100001335144, 116.01746907234192),
#  (0.7105000019073486, 174.02620360851287),
#  (0.7437999844551086, 232.03493814468385),
#  (0.7251999974250793, 290.0436726808548),
#  (0.7396000027656555, 348.05240721702575),
#  (0.7556999921798706, 406.0611417531967),
#  (0.7426999807357788, 464.0698762893677),
#  (0.7710000276565552, 522.0786108255386),
#  (0.766700029373169, 580.0873453617096),
#  '-------------',
#  (0.762499988079071, 161.54314227104186),
#  (0.7937999963760376, 242.31471340656282),
#  (0.786899983882904, 323.0862845420837),
#  (0.7781999707221985, 403.8578556776047),
#  (0.7763000130653381, 484.62942681312563),
#  (0.7742999792098999, 565.4009979486466),
#  (0.7631000280380249, 646.1725690841674),
#  (0.7458999752998352, 726.9441402196884),
#  (0.7777000069618225, 807.7157113552094),
#  '-------------',
#  (0.7752000093460083, 196.4516490459442),
#  (0.7847999930381775, 294.6774735689163),
#  (0.7921000123023987, 392.9032980918884),
# ...
